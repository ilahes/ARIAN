# %% [markdown]
# # 04 — Weather Modeling
#
# **Phase 2, Step 3** of the forecasting pipeline.
#
# **Input:**  `data/processed/weather_features.csv` (from notebook 03)
# **Output:** `models/weather/<target>/<algo>.joblib`, `summary.csv`, `best.json`
#
# ---
#
# ## Ladder of models
#
# We evaluate models of increasing power and keep the best one per target:
#
# | Algo | Purpose |
# |---|---|
# | **Persistence** | `y[t+h] = y[t]` — the floor every model must beat |
# | **Ridge** | Regularised linear — interpretable baseline |
# | **HGBR** | `HistGradientBoostingRegressor` — fast GBM, handles NaNs natively |
# | **XGBoost** | Used if `xgboost` is installed; same class of model, often slightly better |
# | **SARIMA / Prophet** | Per-city classical time-series baselines (optional) |
#
# ## Targets
#
# We forecast 5 daily quantities:
#
# | Target | Daily column | Special handling |
# |---|---|---|
# | `temperature_2m` | `temperature_2m_mean` | — |
# | `wind_speed_10m` | `wind_speed_10m_mean` | — |
# | `wind_direction_10m` | `wind_direction_10m` | **circular MAE** (0-360 wrap) |
# | `rain` | `rain_sum` | Heavy-tailed |
# | `precipitation` | `precipitation_sum` | Heavy-tailed |
#
# ## How leakage is prevented
#
# Every feature was built with `.shift(1).rolling(...)` per city (notebook 03).
# On top of that, this notebook shifts the target **forward** by the forecast
# horizon before training:
#
# ```
# X at row t  (features observed through day t)
# y at row t  =  target[t + horizon]    # what we want to predict
# ```
#
# The train/test split is strictly by feature-row date — no future information
# bleeds into training.

# %% [markdown]
# ## 1. Setup

# %%
# %load_ext autoreload
# %autoreload 2

import sys, warnings
from pathlib import Path
warnings.filterwarnings("ignore")

PROJECT_ROOT = Path.cwd()
while not (PROJECT_ROOT / "src").is_dir() and PROJECT_ROOT != PROJECT_ROOT.parent:
    PROJECT_ROOT = PROJECT_ROOT.parent
sys.path.insert(0, str(PROJECT_ROOT))

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

pd.set_option("display.max_columns", 40)
pd.set_option("display.width", 180)

from src.weather import train as tr
from src.weather.features import DAILY_TARGET_COLUMNS
from src.utils.config import PROCESSED_DIR, MODELS_DIR, FORECAST_TARGETS
from src.utils.logging_utils import get_logger
logger = get_logger("nb.04_modeling")

# %% [markdown]
# ## 2. Load features and show the training schema

# %%
feats = pd.read_csv(PROCESSED_DIR / "weather_features.csv", parse_dates=["date"])
if feats["date"].dt.tz is not None:
    feats["date"] = feats["date"].dt.tz_localize(None)
print(f"Feature matrix: {feats.shape}")
print(f"Forecast targets: {FORECAST_TARGETS}")
# Out:
# Feature matrix: (11500, 495)
# Forecast targets: ['temperature_2m', 'wind_speed_10m', 'wind_direction_10m', 'rain', 'precipitation']

# %%
# Peek at how `prepare_training_frames` shifts targets and splits
tf = tr.prepare_training_frames(
    feats, target="temperature_2m", test_start="2025-01-01", horizon=1,
)
print(f"\nTarget: {tf.target_col} (h={tf.horizon})")
print(f"X_train: {tf.X_train.shape}  y_train: {tf.y_train.shape}")
print(f"X_test : {tf.X_test.shape}   y_test : {tf.y_test.shape}")
print(f"\nFeature-row train window: {tf.train_meta['date'].min().date()}  ->  {tf.train_meta['date'].max().date()}")
print(f"Feature-row test  window: {tf.test_meta['date'].min().date()}  ->  {tf.test_meta['date'].max().date()}")
# Out:
# 00:43:59 | INFO    | src.weather.train | Horizon=1 shift dropped 5 rows (last 1 per city)
# 00:43:59 | INFO    | src.weather.train | Predictor set: 493 columns (target col temperature_2m_mean is included in predictors)
# 00:43:59 | INFO    | src.weather.features | Split 2025-01-01 -> train=7310 rows, test=2360 rows
# 00:43:59 | INFO    | src.weather.train | Prepared temperature_2m h=1: X_train=(7310, 493), X_test=(2360, 493)
# Target: temperature_2m_mean (h=1)
# X_train: (7310, 493)  y_train: (7310,)
# X_test : (2360, 493)   y_test : (2360,)
#
# Feature-row train window: 2020-12-31  ->  2024-12-31
# Feature-row test  window: 2025-01-01  ->  2026-04-17

# %% [markdown]
# ## 3. Train individual models for temperature (walkthrough)
#
# Every trainer returns `(fitted_model, test_predictions)`.  We'll evaluate each
# against the same test set and compare.

# %%
results_temp = {}
for name, trainer in [
    ("persistence", tr.train_persistence),
    ("ridge",       tr.train_ridge),
    ("hgbr",        tr.train_hgbr),
]:
    model, pred = trainer(tf)
    m = tr.evaluate_regression(tf.y_test.values, pred)
    results_temp[name] = {"model": model, "pred": pred, "metrics": m}
    print(f"  {name:12s} MAE={m['MAE']:.3f}  RMSE={m['RMSE']:.3f}  R2={m['R2']:.4f}")
# Out:
#   persistence  MAE=1.252  RMSE=1.729  R2=0.9592
#   ridge        MAE=1.217  RMSE=1.619  R2=0.9642
#   hgbr         MAE=1.166  RMSE=1.572  R2=0.9663

# %% [markdown]
# ### 3a. Diagnostic: predicted vs actual for the best model

# %%
best_name = min(results_temp, key=lambda k: results_temp[k]["metrics"]["RMSE"])
pred = results_temp[best_name]["pred"]
y = tf.y_test.values

fig, ax = plt.subplots(1, 2, figsize=(13, 4))

ax[0].scatter(y, pred, s=3, alpha=0.25, c="steelblue")
lo, hi = min(y.min(), pred.min()), max(y.max(), pred.max())
ax[0].plot([lo, hi], [lo, hi], "k-", lw=1, alpha=0.6, label="perfect")
ax[0].set_xlabel("actual (°C)"); ax[0].set_ylabel("predicted (°C)")
ax[0].set_title(f"temperature_2m  —  {best_name} (MAE={results_temp[best_name]['metrics']['MAE']:.2f}°C)")
ax[0].legend(); ax[0].grid(alpha=0.3)

# Residuals vs date
res = y - pred
ax[1].scatter(tf.test_meta["date"], res, s=3, alpha=0.3, c="darkred")
ax[1].axhline(0, c="k", lw=1)
ax[1].set_xlabel("date"); ax[1].set_ylabel("residual (°C)")
ax[1].set_title("Residuals vs time — look for systematic bias")
ax[1].grid(alpha=0.3)
plt.tight_layout(); plt.show()

# %% [markdown]
# ## 4. Full orchestrator — all targets × all algos
#
# `train_weather_models` iterates over every (target, algo) combination,
# picks the best by test RMSE, and writes artefacts to `models/weather/`.

# %%
summary = tr.train_weather_models(
    algos=["persistence", "ridge", "hgbr", "xgboost"],
    run_cv=True,
    horizon=1,
)
summary.round(3).style.background_gradient(cmap="RdYlGn_r", subset=["RMSE"]) \
       .format(precision=3)
# Out:
# 00:44:12 | INFO    | src.weather.train | ========================================================================
# 00:44:12 | INFO    | src.weather.train | PHASE 2.3 - Weather Modeling (horizon=1 day)
# 00:44:12 | INFO    | src.weather.train | Input: C:\Users\User\Desktop\ARIAN\data\processed\weather_features.csv
# 00:44:12 | INFO    | src.weather.train | ========================================================================
# 00:44:13 | INFO    | src.weather.train | --- target: temperature_2m (circular=False, h=1) ---
# 00:44:14 | INFO    | src.weather.train | Horizon=1 shift dropped 5 rows (last 1 per city)
# 00:44:14 | INFO    | src.weather.train | Predictor set: 493 columns (target col temperature_2m_mean is included in predictors)
# 00:44:14 | INFO    | src.weather.features | Split 2025-01-01 -> train=7310 rows, test=2360 rows
# 00:44:14 | INFO    | src.weather.train | Prepared temperature_2m h=1: X_train=(7310, 493), X_test=(2360, 493)
# 00:44:14 | INFO    | src.weather.train |   training persistence  ...
# 00:44:14 | INFO    | src.weather.train |   persistence MAE=1.252 RMSE=1.729
# 00:44:14 | INFO    | src.weather.train |   training ridge        ...
# 00:44:14 | INFO    | src.weather.train |   Saved temperature_2m/ridge -> C:\Users\User\Desktop\ARIAN\models\weather\temperature_2m\ridge.joblib (0.02 MB)
# 00:44:14 | INFO    | src.weather.train |   ridge MAE=1.217 RMSE=1.619
# 00:44:14 | INFO    | src.weather.train |   training hgbr         ...
# 00:44:44 | INFO    | src.weather.train |   Saved temperature_2m/hgbr -> C:\Users\User\Desktop\ARIAN\models\weather\temperature_2m\hgbr.joblib (1.52 MB)
# 00:44:44 | INFO    | src.weather.train |   hgbr MAE=1.166 RMSE=1.572
# 00:44:44 | INFO    | src.weather.train |   training xgboost      ...
# 00:47:01 | INFO    | src.weather.train |   Saved temperature_2m/xgboost -> C:\Users\User\Desktop\ARIAN\models\weather\temperature_2m\xgboost.joblib (8.28 MB)
# 00:47:01 | INFO    | src.weather.train |   xgboost MAE=1.199 RMSE=1.618
# 00:47:01 | INFO    | src.weather.train |   >>> best for temperature_2m: hgbr (RMSE=1.572)
# 00:47:01 | INFO    | src.weather.train | --- target: wind_speed_10m (circular=False, h=1) ---
# 00:47:01 | INFO    | src.weather.train | Horizon=1 shift dropped 5 rows (last 1 per city)
# 00:47:01 | INFO    | src.weather.train | Predictor set: 493 columns (target col wind_speed_10m_mean is included in predictors)
# 00:47:01 | INFO    | src.weather.features | Split 2025-01-01 -> train=7310 rows, test=2360 rows
# 00:47:01 | INFO    | src.weather.train | Prepared wind_speed_10m h=1: X_train=(7310, 493), X_test=(2360, 493)
# 00:47:01 | INFO    | src.weather.train |   training persistence  ...
# 00:47:01 | INFO    | src.weather.train |   persistence MAE=2.556 RMSE=3.868
# 00:47:01 | INFO    | src.weather.train |   training ridge        ...
# 00:47:02 | INFO    | src.weather.train |   Saved wind_speed_10m/ridge -> C:\Users\User\Desktop\ARIAN\models\weather\wind_speed_10m\ridge.joblib (0.02 MB)
# 00:47:02 | INFO    | src.weather.train |   ridge MAE=2.385 RMSE=3.441
# 00:47:02 | INFO    | src.weather.train |   training hgbr         ...
# 00:47:15 | INFO    | src.weather.train |   Saved wind_speed_10m/hgbr -> C:\Users\User\Desktop\ARIAN\models\weather\wind_speed_10m\hgbr.joblib (1.13 MB)
# 00:47:15 | INFO    | src.weather.train |   hgbr MAE=2.393 RMSE=3.389
# 00:47:15 | INFO    | src.weather.train |   training xgboost      ...
# 00:49:13 | INFO    | src.weather.train |   Saved wind_speed_10m/xgboost -> C:\Users\User\Desktop\ARIAN\models\weather\wind_speed_10m\xgboost.joblib (7.83 MB)
# 00:49:13 | INFO    | src.weather.train |   xgboost MAE=2.483 RMSE=3.484
# 00:49:13 | INFO    | src.weather.train |   >>> best for wind_speed_10m: hgbr (RMSE=3.389)
# 00:49:13 | INFO    | src.weather.train | --- target: wind_direction_10m (circular=True, h=1) ---
# 00:49:13 | INFO    | src.weather.train | Horizon=1 shift dropped 5 rows (last 1 per city)
# 00:49:13 | INFO    | src.weather.train | Predictor set: 490 columns (target col wind_direction_10m is excluded in predictors)
# 00:49:13 | INFO    | src.weather.features | Split 2025-01-01 -> train=7310 rows, test=2360 rows
# 00:49:13 | INFO    | src.weather.train | Prepared wind_direction_10m h=1: X_train=(7310, 490), X_test=(2360, 490)
# 00:49:13 | INFO    | src.weather.train |   training ridge        ...
# 00:49:13 | INFO    | src.weather.train |   Saved wind_direction_10m/ridge -> C:\Users\User\Desktop\ARIAN\models\weather\wind_direction_10m\ridge.joblib (0.02 MB)
# 00:49:13 | INFO    | src.weather.train |   ridge MAE=81.957 RMSE=97.991
# 00:49:13 | INFO    | src.weather.train |   training hgbr         ...
# 00:49:22 | INFO    | src.weather.train |   Saved wind_direction_10m/hgbr -> C:\Users\User\Desktop\ARIAN\models\weather\wind_direction_10m\hgbr.joblib (1.14 MB)
# 00:49:22 | INFO    | src.weather.train |   hgbr MAE=78.135 RMSE=92.893
# 00:49:22 | INFO    | src.weather.train |   training xgboost      ...
# 00:51:29 | INFO    | src.weather.train |   Saved wind_direction_10m/xgboost -> C:\Users\User\Desktop\ARIAN\models\weather\wind_direction_10m\xgboost.joblib (7.91 MB)
# 00:51:29 | INFO    | src.weather.train |   xgboost MAE=79.588 RMSE=94.295
# 00:51:29 | INFO    | src.weather.train |   >>> best for wind_direction_10m: hgbr (RMSE=92.893)
# 00:51:29 | INFO    | src.weather.train | --- target: rain (circular=False, h=1) ---
# 00:51:29 | INFO    | src.weather.train | Horizon=1 shift dropped 5 rows (last 1 per city)
# 00:51:29 | INFO    | src.weather.train | Predictor set: 493 columns (target col rain_sum is included in predictors)
# 00:51:29 | INFO    | src.weather.features | Split 2025-01-01 -> train=7310 rows, test=2360 rows
# 00:51:29 | INFO    | src.weather.train | Prepared rain h=1: X_train=(7310, 493), X_test=(2360, 493)
# 00:51:29 | INFO    | src.weather.train |   training persistence  ...
# 00:51:29 | INFO    | src.weather.train |   persistence MAE=2.404 RMSE=7.196
# 00:51:29 | INFO    | src.weather.train |   training ridge        ...
# 00:51:29 | INFO    | src.weather.train |   Saved rain/ridge -> C:\Users\User\Desktop\ARIAN\models\weather\rain\ridge.joblib (0.02 MB)
# 00:51:29 | INFO    | src.weather.train |   ridge MAE=2.725 RMSE=5.902
# 00:51:29 | INFO    | src.weather.train |   training hgbr         ...
# 00:51:35 | INFO    | src.weather.train |   Saved rain/hgbr -> C:\Users\User\Desktop\ARIAN\models\weather\rain\hgbr.joblib (1.09 MB)
# 00:51:35 | INFO    | src.weather.train |   hgbr MAE=2.395 RMSE=5.813
# 00:51:35 | INFO    | src.weather.train |   training xgboost      ...
# 00:53:11 | INFO    | src.weather.train |   Saved rain/xgboost -> C:\Users\User\Desktop\ARIAN\models\weather\rain\xgboost.joblib (6.56 MB)
# 00:53:11 | INFO    | src.weather.train |   xgboost MAE=2.718 RMSE=5.927
# 00:53:11 | INFO    | src.weather.train |   >>> best for rain: hgbr (RMSE=5.813)
# 00:53:11 | INFO    | src.weather.train | --- target: precipitation (circular=False, h=1) ---
# 00:53:12 | INFO    | src.weather.train | Horizon=1 shift dropped 5 rows (last 1 per city)
# 00:53:12 | INFO    | src.weather.train | Predictor set: 493 columns (target col precipitation_sum is included in predictors)
# 00:53:12 | INFO    | src.weather.features | Split 2025-01-01 -> train=7310 rows, test=2360 rows
# 00:53:12 | INFO    | src.weather.train | Prepared precipitation h=1: X_train=(7310, 493), X_test=(2360, 493)
# 00:53:12 | INFO    | src.weather.train |   training persistence  ...
# 00:53:12 | INFO    | src.weather.train |   persistence MAE=2.635 RMSE=7.377
# 00:53:12 | INFO    | src.weather.train |   training ridge        ...
# 00:53:12 | INFO    | src.weather.train |   Saved precipitation/ridge -> C:\Users\User\Desktop\ARIAN\models\weather\precipitation\ridge.joblib (0.02 MB)
# 00:53:12 | INFO    | src.weather.train |   ridge MAE=2.913 RMSE=6.080
# 00:53:12 | INFO    | src.weather.train |   training hgbr         ...
# 00:53:17 | INFO    | src.weather.train |   Saved precipitation/hgbr -> C:\Users\User\Desktop\ARIAN\models\weather\precipitation\hgbr.joblib (1.07 MB)
# 00:53:17 | INFO    | src.weather.train |   hgbr MAE=2.622 RMSE=5.976
# 00:53:17 | INFO    | src.weather.train |   training xgboost      ...
# 00:54:52 | INFO    | src.weather.train |   Saved precipitation/xgboost -> C:\Users\User\Desktop\ARIAN\models\weather\precipitation\xgboost.joblib (6.73 MB)
# 00:54:52 | INFO    | src.weather.train |   xgboost MAE=2.991 RMSE=6.164
# 00:54:52 | INFO    | src.weather.train |   >>> best for precipitation: hgbr (RMSE=5.976)
# 00:54:52 | INFO    | src.weather.train | ========================================================================
# 00:54:52 | INFO    | src.weather.train | Modeling complete. Summary saved to C:\Users\User\Desktop\ARIAN\models\weather\summary.csv
# 00:54:52 | INFO    | src.weather.train | ========================================================================
# <style type="text/css">
# #T_1b121_row0_col4, #T_1b121_row1_col4, #T_1b121_row2_col4, #T_1b121_row3_col4 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_1b121_row4_col4 {
#   background-color: #06733d;
#   color: #f1f1f1;
# }
# #T_1b121_row5_col4, #T_1b121_row6_col4 {
#   background-color: #04703b;
#   color: #f1f1f1;
# }
# #T_1b121_row7_col4 {
#   background-color: #05713c;
#   color: #f1f1f1;
# }
# #T_1b121_row8_col4 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_1b121_row9_col4 {
#   background-color: #be1827;
#   color: #f1f1f1;
# }
# #T_1b121_row10_col4 {
#   background-color: #b71126;
#   color: #f1f1f1;
# }
# #T_1b121_row11_col4 {
#   background-color: #0e8245;
#   color: #f1f1f1;
# }
# #T_1b121_row12_col4, #T_1b121_row13_col4, #T_1b121_row14_col4, #T_1b121_row16_col4, #T_1b121_row17_col4 {
#   background-color: #0b7d42;
#   color: #f1f1f1;
# }
# #T_1b121_row15_col4 {
#   background-color: #0f8446;
#   color: #f1f1f1;
# }
# #T_1b121_row18_col4 {
#   background-color: #0c7f43;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_1b121">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1b121_level0_col0" class="col_heading level0 col0" >target</th>
#       <th id="T_1b121_level0_col1" class="col_heading level0 col1" >algo</th>
#       <th id="T_1b121_level0_col2" class="col_heading level0 col2" >horizon</th>
#       <th id="T_1b121_level0_col3" class="col_heading level0 col3" >MAE</th>
#       <th id="T_1b121_level0_col4" class="col_heading level0 col4" >RMSE</th>
#       <th id="T_1b121_level0_col5" class="col_heading level0 col5" >R2</th>
#       <th id="T_1b121_level0_col6" class="col_heading level0 col6" >n</th>
#       <th id="T_1b121_level0_col7" class="col_heading level0 col7" >MAPE_pct</th>
#       <th id="T_1b121_level0_col8" class="col_heading level0 col8" >cv_rmse_mean</th>
#       <th id="T_1b121_level0_col9" class="col_heading level0 col9" >cv_rmse_std</th>
#       <th id="T_1b121_level0_col10" class="col_heading level0 col10" >circular_MAE_deg</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1b121_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1b121_row0_col0" class="data row0 col0" >temperature_2m</td>
#       <td id="T_1b121_row0_col1" class="data row0 col1" >persistence</td>
#       <td id="T_1b121_row0_col2" class="data row0 col2" >1</td>
#       <td id="T_1b121_row0_col3" class="data row0 col3" >1.252</td>
#       <td id="T_1b121_row0_col4" class="data row0 col4" >1.729</td>
#       <td id="T_1b121_row0_col5" class="data row0 col5" >0.959</td>
#       <td id="T_1b121_row0_col6" class="data row0 col6" >2360</td>
#       <td id="T_1b121_row0_col7" class="data row0 col7" >51.784</td>
#       <td id="T_1b121_row0_col8" class="data row0 col8" >nan</td>
#       <td id="T_1b121_row0_col9" class="data row0 col9" >nan</td>
#       <td id="T_1b121_row0_col10" class="data row0 col10" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_1b121_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_1b121_row1_col0" class="data row1 col0" >temperature_2m</td>
#       <td id="T_1b121_row1_col1" class="data row1 col1" >ridge</td>
#       <td id="T_1b121_row1_col2" class="data row1 col2" >1</td>
#       <td id="T_1b121_row1_col3" class="data row1 col3" >1.217</td>
#       <td id="T_1b121_row1_col4" class="data row1 col4" >1.619</td>
#       <td id="T_1b121_row1_col5" class="data row1 col5" >0.964</td>
#       <td id="T_1b121_row1_col6" class="data row1 col6" >2360</td>
#       <td id="T_1b121_row1_col7" class="data row1 col7" >45.805</td>
#       <td id="T_1b121_row1_col8" class="data row1 col8" >2.114</td>
#       <td id="T_1b121_row1_col9" class="data row1 col9" >0.394</td>
#       <td id="T_1b121_row1_col10" class="data row1 col10" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_1b121_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_1b121_row2_col0" class="data row2 col0" >temperature_2m</td>
#       <td id="T_1b121_row2_col1" class="data row2 col1" >hgbr</td>
#       <td id="T_1b121_row2_col2" class="data row2 col2" >1</td>
#       <td id="T_1b121_row2_col3" class="data row2 col3" >1.166</td>
#       <td id="T_1b121_row2_col4" class="data row2 col4" >1.572</td>
#       <td id="T_1b121_row2_col5" class="data row2 col5" >0.966</td>
#       <td id="T_1b121_row2_col6" class="data row2 col6" >2360</td>
#       <td id="T_1b121_row2_col7" class="data row2 col7" >35.868</td>
#       <td id="T_1b121_row2_col8" class="data row2 col8" >1.874</td>
#       <td id="T_1b121_row2_col9" class="data row2 col9" >0.349</td>
#       <td id="T_1b121_row2_col10" class="data row2 col10" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_1b121_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_1b121_row3_col0" class="data row3 col0" >temperature_2m</td>
#       <td id="T_1b121_row3_col1" class="data row3 col1" >xgboost</td>
#       <td id="T_1b121_row3_col2" class="data row3 col2" >1</td>
#       <td id="T_1b121_row3_col3" class="data row3 col3" >1.199</td>
#       <td id="T_1b121_row3_col4" class="data row3 col4" >1.618</td>
#       <td id="T_1b121_row3_col5" class="data row3 col5" >0.964</td>
#       <td id="T_1b121_row3_col6" class="data row3 col6" >2360</td>
#       <td id="T_1b121_row3_col7" class="data row3 col7" >39.673</td>
#       <td id="T_1b121_row3_col8" class="data row3 col8" >nan</td>
#       <td id="T_1b121_row3_col9" class="data row3 col9" >nan</td>
#       <td id="T_1b121_row3_col10" class="data row3 col10" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_1b121_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_1b121_row4_col0" class="data row4 col0" >wind_speed_10m</td>
#       <td id="T_1b121_row4_col1" class="data row4 col1" >persistence</td>
#       <td id="T_1b121_row4_col2" class="data row4 col2" >1</td>
#       <td id="T_1b121_row4_col3" class="data row4 col3" >2.556</td>
#       <td id="T_1b121_row4_col4" class="data row4 col4" >3.868</td>
#       <td id="T_1b121_row4_col5" class="data row4 col5" >0.310</td>
#       <td id="T_1b121_row4_col6" class="data row4 col6" >2360</td>
#       <td id="T_1b121_row4_col7" class="data row4 col7" >34.136</td>
#       <td id="T_1b121_row4_col8" class="data row4 col8" >nan</td>
#       <td id="T_1b121_row4_col9" class="data row4 col9" >nan</td>
#       <td id="T_1b121_row4_col10" class="data row4 col10" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_1b121_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_1b121_row5_col0" class="data row5 col0" >wind_speed_10m</td>
#       <td id="T_1b121_row5_col1" class="data row5 col1" >ridge</td>
#       <td id="T_1b121_row5_col2" class="data row5 col2" >1</td>
#       <td id="T_1b121_row5_col3" class="data row5 col3" >2.385</td>
#       <td id="T_1b121_row5_col4" class="data row5 col4" >3.441</td>
#       <td id="T_1b121_row5_col5" class="data row5 col5" >0.454</td>
#       <td id="T_1b121_row5_col6" class="data row5 col6" >2360</td>
#       <td id="T_1b121_row5_col7" class="data row5 col7" >33.608</td>
#       <td id="T_1b121_row5_col8" class="data row5 col8" >6.570</td>
#       <td id="T_1b121_row5_col9" class="data row5 col9" >5.007</td>
#       <td id="T_1b121_row5_col10" class="data row5 col10" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_1b121_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_1b121_row6_col0" class="data row6 col0" >wind_speed_10m</td>
#       <td id="T_1b121_row6_col1" class="data row6 col1" >hgbr</td>
#       <td id="T_1b121_row6_col2" class="data row6 col2" >1</td>
#       <td id="T_1b121_row6_col3" class="data row6 col3" >2.393</td>
#       <td id="T_1b121_row6_col4" class="data row6 col4" >3.389</td>
#       <td id="T_1b121_row6_col5" class="data row6 col5" >0.470</td>
#       <td id="T_1b121_row6_col6" class="data row6 col6" >2360</td>
#       <td id="T_1b121_row6_col7" class="data row6 col7" >36.280</td>
#       <td id="T_1b121_row6_col8" class="data row6 col8" >3.742</td>
#       <td id="T_1b121_row6_col9" class="data row6 col9" >2.106</td>
#       <td id="T_1b121_row6_col10" class="data row6 col10" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_1b121_level0_row7" class="row_heading level0 row7" >7</th>
#       <td

# %% [markdown]
# ### 4a. Best algo per target (from `models/weather/best.json`)

# %%
import json as _json
best = _json.loads((MODELS_DIR / "weather" / "best.json").read_text())
pd.DataFrame([
    {"target": t, "best_algo": d["algo"],
     "RMSE": d["metrics"].get("RMSE"),
     "MAE":  d["metrics"].get("MAE"),
     "R2":   d["metrics"].get("R2"),
     "model_path": d["model_path"]}
    for t, d in best.items()
])
# Out:
#                target best_algo       RMSE        MAE        R2                                         model_path
# 0      temperature_2m      hgbr   1.572282   1.166423  0.966251  C:\Users\User\Desktop\ARIAN\models\weather\tem...
# 1      wind_speed_10m      hgbr   3.388520   2.392851  0.470338  C:\Users\User\Desktop\ARIAN\models\weather\win...
# 2  wind_direction_10m      hgbr  92.893496  78.134644       NaN  C:\Users\User\Desktop\ARIAN\models\weather\win...
# 3                rain      hgbr   5.812629   2.395025  0.141629  C:\Users\User\Desktop\ARIAN\models\weather\rai...
# 4       precipitation      hgbr   5.976338   2.622418  0.153866  C:\Users\User\Desktop\ARIAN\models\weather\pre...

# %% [markdown]
# ## 5. Feature importance — what drives the temperature model?

# %%
import joblib

model_path = MODELS_DIR / "weather" / "temperature_2m" / "hgbr.joblib"
if model_path.exists():
    model = joblib.load(model_path)
    # sklearn's HistGradientBoostingRegressor doesn't expose feature_importances_,
    # but permutation importance on a small validation slice is always available.
    from sklearn.inspection import permutation_importance
    tf_t = tr.prepare_training_frames(feats, "temperature_2m", test_start="2025-01-01", horizon=1)
    # Use a subsample to keep permutation fast
    rng = np.random.default_rng(0)
    idx = rng.choice(len(tf_t.X_test), size=min(500, len(tf_t.X_test)), replace=False)
    imp = permutation_importance(
        model, tf_t.X_test.iloc[idx], tf_t.y_test.iloc[idx],
        n_repeats=5, random_state=0, n_jobs=1,
    )
    imp_df = pd.DataFrame({
        "feature": tf_t.X_test.columns,
        "importance": imp.importances_mean,
        "std": imp.importances_std,
    }).sort_values("importance", ascending=False).head(20)
    print(imp_df.to_string(index=False))
else:
    print(f"Model not found at {model_path} — run the orchestrator above first.")
# Out:
# 00:54:53 | INFO    | src.weather.train | Horizon=1 shift dropped 5 rows (last 1 per city)
# 00:54:53 | INFO    | src.weather.train | Predictor set: 493 columns (target col temperature_2m_mean is included in predictors)
# 00:54:53 | INFO    | src.weather.features | Split 2025-01-01 -> train=7310 rows, test=2360 rows
# 00:54:53 | INFO    | src.weather.train | Prepared temperature_2m h=1: X_train=(7310, 493), X_test=(2360, 493)
#                                  feature  importance      std
#                      temperature_2m_mean    0.865361 0.020661
#           soil_temperature_0_to_7cm_mean    0.043935 0.001999
#                     cloud_cover_mid_mean    0.002089 0.000579
#                        dew_point_2m_mean    0.002056 0.000143
#                       temperature_2m_min    0.001700 0.000328
#                             annual_cos_1    0.001121 0.000387
#              temperature_2m_mean_lag_365    0.001100 0.000169
# soil_temperature_0_to_7cm_mean_roll3_max    0.001073 0.000149
#    soil_temperature_0_to_7cm_mean_lag_14    0.000902 0.000182
#                       temperature_2m_max    0.000895 0.000092
#           temperature_2m_mean_roll7_mean    0.000692 0.000132
#     soil_temperature_0_to_7cm_mean_lag_7    0.000675 0.000293
#                 precipitation_sum_diff_1    0.000675 0.000401
#               temperature_2m_max_lag_365    0.000443 0.000117
#                                city_Guba    0.000434 0.000134
#                  cloud_cover_mean_diff_1    0.000378 0.000125
#               temperature_2m_mean_diff_1    0.000369 0.000224
#             vapour_pressure_deficit_mean    0.000354 0.000186
#      shortwave_radiation_mean_roll30_max    0.000326 0.000124
#                             wind_dir_cos    0.000320 0.000206

# %% [markdown]
# ## 6. Circular metric sanity check — wind direction
#
# For `wind_direction_10m` a model predicting 10° vs a truth of 350° is only
# 20° wrong (wrapping around north), not 340°. The orchestrator uses
# `circular=True` automatically for this target.

# %%
# Run a quick side-by-side to confirm
from src.weather.train import _circular_abs_error_deg
y_t = np.array([350.0, 10.0, 179.0])
y_p = np.array([ 10.0, 350.0, 180.0])
print("Scalar abs error   :", np.abs(y_t - y_p))
print("Circular abs error :", _circular_abs_error_deg(y_t, y_p))
# Out:
# Scalar abs error   : [340. 340.   1.]
# Circular abs error : [20. 20.  1.]

# %% [markdown]
# ## 7. Multi-horizon extension (optional)
#
# Our training harness takes a `horizon` argument. The orchestrator currently
# trains only at h=1 (tomorrow). To train a full 1-30 day ladder:
#
# ```python
# horizon_summaries = []
# for h in (1, 3, 7, 14, 30):
#     s = tr.train_weather_models(horizon=h, run_cv=False,
#                                 algos=["persistence", "ridge", "hgbr"])
#     horizon_summaries.append(s)
# ```
#
# We'll wire this into the forecasting step (notebook 05) where we need to
# predict across a full 30-day horizon anyway.

# %% [markdown]
# ## 8. Persisted artefacts

# %%
from pathlib import Path
artefacts = sorted((MODELS_DIR / "weather").rglob("*"))
rows = []
for p in artefacts:
    if p.is_file():
        rows.append({"path": str(p.relative_to(MODELS_DIR)), "size_KB": round(p.stat().st_size / 1024, 1)})
pd.DataFrame(rows)
# Out:
#                                           path  size_KB
# 0                            weather\best.json      1.6
# 1            weather\multi_horizon_summary.csv      4.2
# 2         weather\precipitation\h1\hgbr.joblib   1190.1
# 3        weather\precipitation\h14\hgbr.joblib   1186.6
# 4         weather\precipitation\h3\hgbr.joblib   1114.9
# 5        weather\precipitation\h30\hgbr.joblib   1212.9
# 6         weather\precipitation\h7\hgbr.joblib   1090.5
# 7            weather\precipitation\hgbr.joblib   1092.3
# 8           weather\precipitation\ridge.joblib     19.1
# 9         weather\precipitation\xgboost.joblib   6886.8
# 10                 weather\rain\h1\hgbr.joblib   1082.0
# 11                weather\rain\h14\hgbr.joblib   1270.0
# 12                 weather\rain\h3\hgbr.joblib   1227.3
# 13                weather\rain\h30\hgbr.joblib   1217.9
# 14                 weather\rain\h7\hgbr.joblib   1116.1
# 15                    weather\rain\hgbr.joblib   1117.0
# 16                   weather\rain\ridge.joblib     19.1
# 17                 weather\rain\xgboost.joblib   6722.5
# 18                         weather\summary.csv      2.2
# 19       weather\temperature_2m\h1\hgbr.joblib   1625.9
# 20      weather\temperature_2m\h14\hgbr.joblib   1595.9
# 21       weather\temperature_2m\h3\hgbr.joblib   1594.2
# 22      weather\temperature_2m\h30\hgbr.joblib   1584.3
# 23       weather\temperature_2m\h7\hgbr.joblib   1581.2
# 24          weather\temperature_2m\hgbr.joblib   1557.3
# 25         weather\temperature_2m\ridge.joblib     19.1
# 26       weather\temperature_2m\xgboost.joblib   8482.3
# 27   weather\wind_direction_10m\h1\hgbr.joblib   1180.9
# 28  weather\wind_direction_10m\h14\hgbr.joblib   1145.7
# 29   weather\wind_direction_10m\h3\hgbr.joblib   1138.6
# 30  weather\wind_direction_10m\h30\hgbr.joblib   1112.0
# 31   weather\wind_direction_10m\h7\hgbr.joblib   1305.2
# 32      weather\wind_direction_10m\hgbr.joblib   1170.5
# 33     weather\wind_direction_10m\ridge.joblib     19.0
# 34   weather\wind_direction_10m\xgboost.joblib   8096.7
# 35       weather\wind_speed_10m\h1\hgbr.joblib   1160.8
# 36      weather\wind_speed_10m\h14\hgbr.joblib   1205.3
# 37       weather\wind_speed_10m\h3\hgbr.joblib   1140.5
# 38      weather\wind_speed_10m\h30\hgbr.joblib   1288.8
# 39       weather\wind_speed_10m\h7\hgbr.joblib   1135.8
# 40          weather\wind_speed_10m\hgbr.joblib   1160.8
# 41         weather\wind_speed_10m\ridge.joblib     19.1
# 42       weather\wind_speed_10m\xgboost.joblib   8022.2

# %% [markdown]
# ---
# **Step 3 of Phase 2 ✅ complete.** Next: `05_weather_forecasting.ipynb` — produce a
# 30-day forward forecast by recursively applying the trained models, and persist
# `data/processed/weather_forecast.csv`.
